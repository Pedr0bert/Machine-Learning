# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedr0bert/Machine-Learning/blob/main/DeepLearning_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **This program runs a simple prediction DL model with one neuron**

# %%
import tensorflow as tf
import keras
import numpy as np

# %%
model = tf.keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(units = 1)
])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
x = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
y = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

# %%
model.fit(x, y, epochs = 700)
# Out:
# Epoch 1/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - loss: 35.9799
# Epoch 2/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 28.6457
# Epoch 3/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 22.8685
# Epoch 4/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 18.3165
# Epoch 5/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 14.7286
# Epoch 6/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 11.8992
# Epoch 7/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 9.6668
# Epoch 8/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 7.9042
# Epoch 9/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.5113
# Epoch 10/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.4094
# Epoch 11/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.5366
# Epoch 12/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.8442
# Epoch 13/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.2938
# Epoch 14/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.8552
# Epoch 15/700
# ...

# %%
print(f'model predicted: {model.predict(np.array([10.0]), verbose= 0).item():.5f}')
# Out:
# model predicted: 18.99998
